# %%
scale = 4

paper_size = (595, 842)
qr_size = (54, 54)

xs = [
    20.5,
    89,
    157.5,
    226,
    314.5,
    383,
    451.5,
    520
]
ys = [
    67,
    176,
    285,
    394,
    503,
    612,
    721
]

paper_size = [int(x * scale) for x in paper_size]
qr_size = [int(x * scale) for x in qr_size]
qr_map = [[int(x * scale), int(y * scale)] for x in xs for y in ys]

# %%
import random
import string
import qrcode

rand_chars = string.ascii_letters + string.digits

used_ids = set()

def make_qr():
    while True:
        id = ''.join(random.choice(rand_chars) for _ in range(5))
        
        if id not in used_ids:
            break

    used_ids.add(id)

    qr = qrcode.QRCode(
        border=0,
    )
    qr.add_data(id)
    qr.make(fit=True)
    img = qr.make_image(back_color="transparent")
    img = img.resize(qr_size, resample=0)

    return id, img


def make_page():
    page = Image.new('RGBA', paper_size, (255, 255, 255, 255))
    for x, y in qr_map:
        id, img = make_qr()
        page.paste(img, (x, y), img)

    return page

# %%
from PIL import Image
from IPython.display import display
import os

used_ids = set()
count = 300
i = 0

os.makedirs('../추첨QR', exist_ok=True)

while len(used_ids) < 300:
    page = make_page()
    page.save(f'../추첨QR/{i}.png')
    display(page)
    i += 1
# Out:
# <PIL.Image.Image image mode=RGBA size=2380x3368>
# <PIL.Image.Image image mode=RGBA size=2380x3368>
# <PIL.Image.Image image mode=RGBA size=2380x3368>
# <PIL.Image.Image image mode=RGBA size=2380x3368>
# <PIL.Image.Image image mode=RGBA size=2380x3368>
# <PIL.Image.Image image mode=RGBA size=2380x3368>

# %%
import json

with open('../추첨QR/ids.json', 'w') as f:
    json.dump(list(used_ids), f)

# %%
import json

with open('../추첨QR/ids.json', 'r') as f:
    data = json.load(f)

sqls = []

for id in data:
    sqls.append(f"INSERT INTO `luckytokens` (`token`) VALUES ('{id}');")

print('\n'.join(sqls))
# Out:
# INSERT INTO `luckytokens` (`token`) VALUES ('u06fG');
# INSERT INTO `luckytokens` (`token`) VALUES ('gVTsl');
# INSERT INTO `luckytokens` (`token`) VALUES ('qa8AP');
# INSERT INTO `luckytokens` (`token`) VALUES ('BsMWQ');
# INSERT INTO `luckytokens` (`token`) VALUES ('sPTh3');
# INSERT INTO `luckytokens` (`token`) VALUES ('tYv0C');
# INSERT INTO `luckytokens` (`token`) VALUES ('q439q');
# INSERT INTO `luckytokens` (`token`) VALUES ('L6n9F');
# INSERT INTO `luckytokens` (`token`) VALUES ('6bB97');
# INSERT INTO `luckytokens` (`token`) VALUES ('rwUru');
# INSERT INTO `luckytokens` (`token`) VALUES ('M91ao');
# INSERT INTO `luckytokens` (`token`) VALUES ('MNoij');
# INSERT INTO `luckytokens` (`token`) VALUES ('Ch5Yz');
# INSERT INTO `luckytokens` (`token`) VALUES ('UKaLO');
# INSERT INTO `luckytokens` (`token`) VALUES ('gCi6o');
# INSERT INTO `luckytokens` (`token`) VALUES ('bG0IQ');
# INSERT INTO `luckytokens` (`token`) VALUES ('gTc4N');
# INSERT INTO `luckytokens` (`token`) VALUES ('YEs7C');
# INSERT INTO `luckytokens` (`token`) VALUES ('hCcxg');
# INSERT INTO `luckytokens` (`token`) VALUES ('hhdmu');
# INSERT INTO `luckytokens` (`token`) VALUES ('ZzZdV');
# INSERT INTO `luckytokens` (`token`) VALUES ('otAlI');
# INSERT INTO `luckytokens` (`token`) VALUES ('7Umrp');
# INSERT INTO `luckytokens` (`token`) VALUES ('sashM');
# INSERT INTO `luckytokens` (`token`) VALUES ('8S3w5');
# INSERT INTO `luckytokens` (`token`) VALUES ('PI5fc');
# INSERT INTO `luckytokens` (`token`) VALUES ('vWFP2');
# INSERT INTO `luckytokens` (`token`) VALUES ('Lhu9B');
# INSERT INTO `luckytokens` (`token`) VALUES ('7n2UU');
# INSERT INTO `luckytokens` (`token`) VALUES ('JgTzo');
# INSERT INTO `luckytokens` (`token`) VALUES ('TFHyG');
# INSERT INTO `luckytokens` (`token`) VALUES ('Ppw7j');
# INSERT INTO `luckytokens` (`token`) VALUES ('NORqp');
# INSERT INTO `luckytokens` (`token`) VALUES ('kLOcO');
# INSERT INTO `luckytokens` (`token`) VALUES ('RvXdJ');
# INSERT INTO `luckytokens` (`token`) VALUES ('dfnB2');
# INSERT INTO `luckytokens` (`token`) VALUES ('9pauM');
# INSERT INTO `luckytokens` (`token`) VALUES ('Du7Rz');
# INSERT INTO `luckytokens` (`token`) VALUES ('z4Zeb');
# INSERT INTO `luckytokens` (`token`) VALUES ('eoK2l');
# INSERT INTO `luckytokens` (`token`) VALUES ('r5u7S');
# INSERT INTO `luckytokens` (`token`) VALUES ('XlRHK');
# INSERT INTO `luckytokens` (`token`) VALUES ('JT39s');
# INSERT INTO `luckytokens` (`token`) VALUES ('65l8Q');
# INSERT INTO `luckytokens` (`token`) VALUES ('LcJ3Z');
# INSERT INTO `luckytokens` (`token`) VALUES ('lchkn');
# INSERT INTO `luckytokens` (`token`) VALUES ('jYqNS');
# INSERT INTO `luckytokens` (`token`) VALUES ('HxTgO');
# INSERT INTO `luckytokens` (`token`) VALUES ('5wMSZ');
# INSERT INTO `luckytokens` (`token`) VALUES ('1LEYR');
# INSERT INTO `luckytokens` (`token`) VALUES ('2Ercs');
# INSERT INTO `luckytokens` (`token`) VALUES ('mnHAO');
# INSERT INTO `luckytokens` (`token`) VALUES ('LwNqP');
# INSERT INTO `luckytokens` (`token`) VALUES ('BNQ4u');
# INSERT INTO `luckytokens` (`token`) VALUES ('LdTNL');
# INSERT INTO `luckytokens` (`token`) VALUES ('X7ehr');
# INSERT INTO `luckytokens` (`token`) VALUES ('DH82y');
# INSERT INTO `luckytokens` (`token`) VALUES ('devYS');
# INSERT INTO `luckytokens` (`token`) VALUES ('QZH41');
# INSERT INTO `luckytokens` (`token`) VALUES ('pS6bl');
# INSERT INTO `luckytokens` (`token`) VALUES ('rpUSQ');
# INSERT INTO `luckytokens` (`token`) VALUES ('IGTPW');
# INSERT INTO `luckytokens` (`token`) VALUES ('c2zrZ');
# INSERT INTO `luckytokens` (`token`) VALUES ('7aZ6X');
# INSERT INTO `luckytokens` (`token`) VALUES ('DNOkn');
# INSERT INTO `luckytokens` (`token`) VALUES ('IvFC0');
# INSERT INTO `luckytokens` (`token`) VALUES ('SfBdV');
# INSERT INTO `luckytokens` (`token`) VALUES ('rI8ZR');
# INSERT INTO `luckytokens` (`token`) VALUES ('0qd6g');
# INSERT INTO `luckytokens` (`token`) VALUES ('LX1XJ');
# INSERT INTO `luckytokens` (`token`) VALUES ('OBQh6');
# INSERT INTO `luckytokens` (`token`) VALUES ('tthZW');
# INSERT INTO `luckytokens` (`token`) VALUES ('2ibYl');
# INSERT INTO `luckytokens` (`token`) VALUES ('rzsSj');
# INSERT INTO `luckytokens` (`token`) VALUES ('4nXbB');
# INSERT INTO `luckytokens` (`token`) VALUES ('JObe6');
# INSERT INTO `luckytokens` (`token`) VALUES ('DfB5a');
# INSERT INTO `luckytokens` (`token`) VALUES ('FB67P');
# INSERT INTO `luckytokens` (`token`) VALUES ('prRj0');
# INSERT INTO `luckytokens` (`token`) VALUES ('1AEih');
# INSERT INTO `luckytokens` (`token`) VALUES ('rpgc1');
# INSERT INTO `luckytokens` (`token`) VALUES ('0wGl7');
# INSERT INTO `luckytokens` (`token`) VALUES ('r9DCb');
# INSERT INTO `luckytokens` (`token`) VALUES ('cErwj');
# INSERT INTO `luckytokens` (`token`) VALUES ('8osDp');
# INSERT INTO `luckytokens` (`token`) VALUES ('kyiZw');
# INSERT INTO `luckytokens` (`token`) VALUES ('vCTVc');
# INSERT INTO `luckytokens` (`token`) VALUES ('mH4D5');
# INSERT INTO `luckytokens` (`token`) VALUES ('pbxob');
# INSERT INTO `luckytokens` (`token`) VALUES ('sGA14');
# INSERT INTO `luckytokens` (`token`) VALUES ('d1VVu');
# INSERT INTO `luckytokens` (`token`) VALUES ('IY4vi');
# INSERT INTO `luckytokens` (`token`) VALUES ('eN4wl');
# INSERT INTO `luckytokens` (`token`) VALUES ('nvUWk');
# INSERT INTO `luckytokens` (`token`) VALUES ('Ud2NY');
# INSERT INTO `luckytokens` (`token`) VALUES ('ZTYNn');
# INSERT INTO `luckytokens` (`token`) VALUES ('vqtjr');
# INSERT INTO `luckytokens` (`token`) VALUES ('VTveh');
# INSERT INTO `luckytokens` (`token`) VALUES ('MKxKd');
# INSERT INTO `luckytokens` (`token`) VALUES ('nApu4');
# INSERT INTO `luckytokens` (`token`) VALUES ('Ya770');
# INSERT INTO `luckytokens` (`token`) VALUES ('LdJs0');
# INSERT INTO `luckytokens` (`token`) VALUES ('gmOIX');
# INSERT INTO `luckytokens` (`token`) VALUES ('dEVd2');
# INSERT INTO `luckytokens` (`token`) VALUES ('XBgBM');
# INSERT INTO `luckytokens` (`token`) VALUES ('tRAHT');
# INSERT INTO `luckytokens` (`token`) VALUES ('absl6');
# INSERT INTO `luckytokens` (`token`) VALUES ('fYPXB');
# INSERT INTO `luckytokens` (`token`) VALUES ('wQS4H');
# INSERT INTO `luckytokens` (`token`) VALUES ('v7bFt');
# INSERT INTO `luckytokens` (`token`) VALUES ('3CTTC');
# INSERT INTO `luckytokens` (`token`) VALUES ('N9fh2');
# INSERT INTO `luckytokens` (`token`) VALUES ('5gK2K');
# INSERT INTO `luckytokens` (`token`) VALUES ('zIOng');
# INSERT INTO `luckytokens` (`token`) VALUES ('hs6q6');
# INSERT INTO `luckytokens` (`token`) VALUES ('DgShK');
# INSERT INTO `luckytokens` (`token`) VALUES ('lkkNK');
# INSERT INTO `luckytokens` (`token`) VALUES ('uSPxw');
# INSERT INTO `luckytokens` (`token`) VALUES ('FpfBu');
# INSERT INTO `luckytokens` (`token`) VALUES ('YuRGI');
# INSERT INTO `luckytokens` (`token`) VALUES ('9Z5wV');
# INSERT INTO `luckytokens` (`token`) VALUES ('BSxpi');
# INSERT INTO `luckytokens` (`token`) VALUES ('YinwD');
# INSERT INTO `luckytokens` (`token`) VALUES ('eiPqF');
# INSERT INTO `luckytokens` (`token`) VALUES ('wMbTl');
# INSERT INTO `luckytokens` (`token`) VALUES ('5oii4');
# INSERT INTO `luckytokens` (`token`) VALUES ('CBxYI');
# INSERT INTO `luckytokens` (`token`) VALUES ('fdsWN');
# INSERT INTO `luckytokens` (`token`) VALUES ('7sgsk');
# INSERT INTO `luckytokens` (`token`) VALUES ('Sr3Rf');
# INSERT INTO `luckytokens` (`token`) VALUES ('SBFyl');
# INSERT INTO `luckytokens` (`token`) VALUES ('lNqnS');
# INSERT INTO `luckytokens` (`token`) VALUES ('w5UEY');
# INSERT INTO `luckytokens` (`token`) VALUES ('qDfbs');
# INSERT INTO `luckytokens` (`token`) VALUES ('ayNy9');
# INSERT INTO `luckytokens` (`token`) VALUES ('MBbma');
# INSERT INTO `luckytokens` (`token`) VALUES ('qVYTX');
# INSERT INTO `luckytokens` (`token`) VALUES ('pjDkx');
# INSERT INTO `luckytokens` (`token`) VALUES ('ca6es');
# INSERT INTO `luckytokens` (`token`) VALUES ('WRvHR');
# INSERT INTO `luckytokens` (`token`) VALUES ('9vlq8');
# INSERT INTO `luckytokens` (`token`) VALUES ('T8B3s');
# INSERT INTO `luckytokens` (`token`) VALUES ('5VVrd');
# INSERT INTO `luckytokens` (`token`) VALUES ('DYMv5');
# INSERT INTO `luckytokens` (`token`) VALUES ('D6j8A');
# INSERT INTO `luckytokens` (`token`) VALUES ('Yrd8M');
# INSERT INTO `luckytokens` (`token`) VALUES ('fsbMP');
# INSERT INTO `luckytokens` (`token`) VALUES ('KnSSw');
# INSERT INTO `luckytokens` (`token`) VALUES ('nhxyu');
# INSERT INTO `luckytokens` (`token`) VALUES ('R1QZ5');
# INSERT INTO `luckytokens` (`token`) VALUES ('NTwcf');
# INSERT INTO `luckytokens` (`token`) VALUES ('M2rEb');
# INSERT INTO `luckytokens` (`token`) VALUES ('jn4eA');
# INSERT INTO `luckytokens` (`token`) VALUES ('SrdfO');
# INSERT INTO `luckytokens` (`token`) VALUES ('AKhoB');
# INSERT INTO `luckytokens` (`token`) VALUES ('9WFJq');
# INSERT INTO `luckytokens` (`token`) VALUES ('PDzxz');
# INSERT INTO `luckytokens` (`token`) VALUES ('BNCpl');
# INSERT INTO `luckytokens` (`token`) VALUES ('jNJGP');
# INSERT INTO `luckytokens` (`token`) VALUES ('UVZYp');
# INSERT INTO `luckytokens` (`token`) VALUES ('uO0FV');
# INSERT INTO `luckytokens` (`token`) VALUES ('qblM9');
# INSERT INTO `luckytokens` (`token`) VALUES ('EjtRv');
# INSERT INTO `luckytokens` (`token`) VALUES ('npbjT');
# INSERT INTO `luckytokens` (`token`) VALUES ('ua138');
# INSERT INTO `luckytokens` (`token`) VALUES ('5NpkR');
# INSERT INTO `luckytokens` (`token`) VALUES ('fq4dy');
# INSERT INTO `luckytokens` (`token`) VALUES ('feEQk');
# INSERT INTO `luckytokens` (`token`) VALUES ('RKmIO');
# INSERT INTO `luckytokens` (`token`) VALUES ('Wudrn');
# INSERT INTO `luckytokens` (`token`) VALUES ('6xZr7');
# INSERT INTO `luckytokens` (`token`) VALUES ('eamr7');
# INSERT INTO `luckytokens` (`token`) VALUES ('sV5n9');
# INSERT INTO `luckytokens` (`token`) VALUES ('a7RWI');
# INSERT INTO `luckytokens` (`token`) VALUES ('tGKOw');
# INSERT INTO `luckytokens` (`token`) VALUES ('o0LS5');
# INSERT INTO `luckytokens` (`token`) VALUES ('2cNq0');
# INSERT INTO `luckytokens` (`token`) VALUES ('CJOXB');
# INSERT INTO `luckytokens` (`token`) VALUES ('afa6h');
# INSERT INTO `luckytokens` (`token`) VALUES ('EIkP2');
# INSERT INTO `luckytokens` (`token`) VALUES ('o81zJ');
# INSERT INTO `luckytokens` (`token`) VALUES ('rYg2D');
# INSERT INTO `luckytokens` (`token`) VALUES ('XzVAx');
# INSERT INTO `luckytokens` (`token`) VALUES ('Tcror');
# INSERT INTO `luckytokens` (`token`) VALUES ('Kzanb');
# INSERT INTO `luckytokens` (`token`) VALUES ('OBiaV');
# INSERT INTO `luckytokens` (`token`) VALUES ('ew5eo');
# INSERT INTO `luckytokens` (`token`) VALUES ('yP7Jf');
# INSERT INTO `luckytokens` (`token`) VALUES ('vFdc4');
# INSERT INTO `luckytokens` (`token`) VALUES ('u8VGU');
# INSERT INTO `luckytokens` (`token`) VALUES ('S0VQz');
# INSERT INTO `luckytokens` (`token`) VALUES ('dqZKz');
# INSERT INTO `luckytokens` (`token`) VALUES ('L75eb');
# INSERT INTO `luckytokens` (`token`) VALUES ('sQd9D');
# INSERT INTO `luckytokens` (`token`) VALUES ('FUBPQ');
# INSERT INTO `luckytokens` (`token`) VALUES ('EDnir');
# INSERT INTO `luckytokens` (`token`) VALUES ('35roM');
# INSERT INTO `luckytokens` (`token`) VALUES ('3q3WW');
# INSERT INTO `luckytokens` (`token`) VALUES ('UubKC');
# INSERT INTO `luckytokens` (`token`) VALUES ('0RROY');
# INSERT INTO `luckytokens` (`token`) VALUES ('pSf2d');
# INSERT INTO `luckytokens` (`token`) VALUES ('ve0Yh');
# INSERT INTO `luckytokens` (`token`) VALUES ('MLZiD');
# INSERT INTO `luckytokens` (`token`) VALUES ('1Zrkd');
# INSERT INTO `luckytokens` (`token`) VALUES ('dg1e4');
# INSERT INTO `luckytokens` (`token`) VALUES ('G74Xo');
# INSERT INTO `luckytokens` (`token`) VALUES ('atoRk');
# INSERT INTO `luckytokens` (`token`) VALUES ('vQgQB');
# INSERT INTO `luckytokens` (`token`) VALUES ('9K1dK');
# INSERT INTO `luckytokens` (`token`) VALUES ('4KIkm');
# INSERT INTO `luckytokens` (`token`) VALUES ('PjIZh');
# INSERT INTO `luckytokens` (`token`) VALUES ('EQIeR');
# INSERT INTO `luckytokens` (`token`) VALUES ('GGDZ9');
# INSERT INTO `luckytokens` (`token`) VALUES ('QyXqQ');
# INSERT INTO `luckytokens` (`token`) VALUES ('AvuEX');
# INSERT INTO `luckytokens` (`token`) VALUES ('kjGzl');
# INSERT INTO `luckytokens` (`token`) VALUES ('BOYk9');
# INSERT INTO `luckytokens` (`token`) VALUES ('1UTFf');
# INSERT INTO `luckytokens` (`token`) VALUES ('F2k0N');
# INSERT INTO `luckytokens` (`token`) VALUES ('utuDT');
# INSERT INTO `luckytokens` (`token`) VALUES ('OH5S3');
# INSERT INTO `luckytokens` (`token`) VALUES ('UgaN5');
# INSERT INTO `luckytokens` (`token`) VALUES ('nVDiY');
# INSERT INTO `luckytokens` (`token`) VALUES ('ceJ54');
# INSERT INTO `luckytokens` (`token`) VALUES ('ykj1a');
# INSERT INTO `luckytokens` (`token`) VALUES ('zeI8n');
# INSERT INTO `luckytokens` (`token`) VALUES ('gMS2T');
# INSERT INTO `luckytokens` (`token`) VALUES ('3JGAt');
# INSERT INTO `luckytokens` (`token`) VALUES ('bV2jA');
# INSERT INTO `luckytokens` (`token`) VALUES ('sofkU');
# INSERT INTO `luckytokens` (`token`) VALUES ('6WI08');
# INSERT INTO `luckytokens` (`token`) VALUES ('VQrvO');
# INSERT INTO `luckytokens` (`token`) VALUES ('qlQPD');
# INSERT INTO `luckytokens` (`token`) VALUES ('s66LB');
# INSERT INTO `luckytokens` (`token`) VALUES ('r4c5t');
# INSERT INTO `luckytokens` (`token`) VALUES ('1Xjc6');
# INSERT INTO `luckytokens` (`token`) VALUES ('HeaOP');
# INSERT INTO `luckytokens` (`token`) VALUES ('KsT7z');
# INSERT INTO `luckytokens` (`token`) VALUES ('a4Z56');
# INSERT INTO `luckytokens` (`token`) VALUES ('9MevT');
# INSERT INTO `luckytokens` (`token`) VALUES ('izPw2');
# INSERT INTO `luckytokens` (`token`) VALUES ('2sb1e');
# INSERT INTO `luckytokens` (`token`) VALUES ('P3Md3');
# INSERT INTO `luckytokens` (`token`) VALUES ('xTre4');
# INSERT INTO `luckytokens` (`token`) VALUES ('7hYWf');
# INSERT INTO `luckytokens` (`token`) VALUES ('4uZ1j');
# INSERT INTO `luckytokens` (`token`) VALUES ('7CWIT');
# INSERT INTO `luckytokens` (`token`) VALUES ('KnbJC');
# INSERT INTO `luckytokens` (`token`) VALUES ('aXn8P');
# INSERT INTO `luckytokens` (`token`) VALUES ('AJHXh');
# INSERT INTO `luckytokens` (`token`) VALUES ('exy92');
# INSERT INTO `luckytokens` (`token`) VALUES ('ur1VC');
# INSERT INTO `luckytokens` (`token`) VALUES ('403ip');
# INSERT INTO `luckytokens` (`token`) VALUES ('eY4vw');
# INSERT INTO `luckytokens` (`token`) VALUES ('JAqqo');
# INSERT INTO `luckytokens` (`token`) VALUES ('FnTH8');
# INSERT INTO `luckytokens` (`token`) VALUES ('oVE4N');
# INSERT INTO `luckytokens` (`token`) VALUES ('GYcZC');
# INSERT INTO `luckytokens` (`token`) VALUES ('2NLdx');
# INSERT INTO `luckytokens` (`token`) VALUES ('ef2X5');
# INSERT INTO `luckytokens` (`token`) VALUES ('VbOPg');
# INSERT INTO `luckytokens` (`token`) VALUES ('Tn33L');
# INSERT INTO `luckytokens` (`token`) VALUES ('YWXeS');
# INSERT INTO `luckytokens` (`token`) VALUES ('XE0pR');
# INSERT INTO `luckytokens` (`token`) VALUES ('MeTvz');
# INSERT INTO `luckytokens` (`token`) VALUES ('JfMmP');
# INSERT INTO `luckytokens` (`token`) VALUES ('efeJE');
# INSERT INTO `luckytokens` (`token`) VALUES ('kVfbc');
# INSERT INTO `luckytokens` (`token`) VALUES ('ac59N');
# INSERT INTO `luckytokens` (`token`) VALUES ('8MvZB');
# INSERT INTO `luckytokens` (`token`) VALUES ('ihX5o');
# INSERT INTO `luckytokens` (`token`) VALUES ('yFOPL');
# INSERT INTO `luckytokens` (`token`) VALUES ('mQQV5');
# INSERT INTO `luckytokens` (`token`) VALUES ('W3usS');
# INSERT INTO `luckytokens` (`token`) VALUES ('qwTor');
# INSERT INTO `luckytokens` (`token`) VALUES ('OceZn');
# INSERT INTO `luckytokens` (`token`) VALUES ('FERTJ');
# INSERT INTO `luckytokens` (`token`) VALUES ('QeOBm');
# INSERT INTO `luckytokens` (`token`) VALUES ('DbguR');
# INSERT INTO `luckytokens` (`token`) VALUES ('DABZn');
# INSERT INTO `luckytokens` (`token`) VALUES ('6EOpW');
# INSERT INTO `luckytokens` (`token`) VALUES ('Cyilb');
# INSERT INTO `luckytokens` (`token`) VALUES ('7lGiT');
# INSERT INTO `luckytokens` (`token`) VALUES ('UVQf0');
# INSERT INTO `luckytokens` (`token`) VALUES ('ELfWG');
# INSERT INTO `luckytokens` (`token`) VALUES ('Bl9QC');
# INSERT INTO `luckytokens` (`token`) VALUES ('ZFXBf');
# INSERT INTO `luckytokens` (`token`) VALUES ('t93DX');
# INSERT INTO `luckytokens` (`token`) VALUES ('OsrfN');
# INSERT INTO `luckytokens` (`token`) VALUES ('CnElz');
# INSERT INTO `luckytokens` (`token`) VALUES ('ADMcC');
# INSERT INTO `luckytokens` (`token`) VALUES ('A00by');
# INSERT INTO `luckytokens` (`token`) VALUES ('28wyA');
# INSERT INTO `luckytokens` (`token`) VALUES ('EtOw1');
# INSERT INTO `luckytokens` (`token`) VALUES ('JIUKY');
# INSERT INTO `luckytokens` (`token`) VALUES ('R4RRr');
# INSERT INTO `luckytokens` (`token`) VALUES ('uWhq4');
# INSERT INTO `luckytokens` (`token`) VALUES ('dwLTw');
# INSERT INTO `luckytokens` (`token`) VALUES ('idJ9w');
# INSERT INTO `luckytokens` (`token`) VALUES ('4dBRU');
# INSERT INTO `luckytokens` (`token`) VALUES ('cjErf');
# INSERT INTO `luckytokens` (`token`) VALUES ('NVpEw');
# INSERT INTO `luckytokens` (`token`) VALUES ('Y2yPc');
# INSERT INTO `luckytokens` (`token`) VALUES ('swUEi');
# INSERT INTO `luckytokens` (`token`) VALUES ('h15eh');
# INSERT INTO `luckytokens` (`token`) VALUES ('Yc4FV');
# INSERT INTO `luckytokens` (`token`) VALUES ('aMcxA');
# INSERT INTO `luckytokens` (`token`) VALUES ('fJEtx');
# INSERT INTO `luckytokens` (`token`) VALUES ('DsEtf');
# INSERT INTO `luckytokens` (`token`) VALUES ('JmjAL');
# INSERT INTO `luckytokens` (`token`) VALUES ('VvOeK');
# INSERT INTO `luckytokens` (`token`) VALUES ('7cVE9');
# INSERT INTO `luckytokens` (`token`) VALUES ('ugnHO');
# INSERT INTO `luckytokens` (`token`) VALUES ('omNgj');
# INSERT INTO `luckytokens` (`token`) VALUES ('fkBzD');
# INSERT INTO `luckytokens` (`token`) VALUES ('1pCf7');
# INSERT INTO `luckytokens` (`token`) VALUES ('4KmBy');
# INSERT INTO `luckytokens` (`token`) VALUES ('4vcHN');
# INSERT INTO `luckytokens` (`token`) VALUES ('FeSN2');
# INSERT INTO `luckytokens` (`token`) VALUES ('j5ZvY');
# INSERT INTO `luckytokens` (`token`) VALUES ('Fu7Q9');
# INSERT INTO `luckytokens` (`token`) VALUES ('S3ASX');
# INSERT INTO `luckytokens` (`token`) VALUES ('JePv8');
# INSERT INTO `luckytokens` (`token`) VALUES ('uoT1p');
# INSERT INTO `luckytokens` (`token`) VALUES ('uML9s');
# INSERT INTO `luckytokens` (`token`) VALUES ('eoGPg');
# INSERT INTO `luckytokens` (`token`) VALUES ('1RykG');
# INSERT INTO `luckytokens` (`token`) VALUES ('0q9iz');
# INSERT INTO `luckytokens` (`token`) VALUES ('dh3v9');
# INSERT INTO `luckytokens` (`token`) VALUES ('vEmHN');
# INSERT INTO `luckytokens` (`token`) VALUES ('vgCDL');
# INSERT INTO `luckytokens` (`token`) VALUES ('UCxxC');
# INSERT INTO `luckytokens` (`token`) VALUES ('Aj7Ze');
# INSERT INTO `luckytokens` (`token`) VALUES ('ivTdo');
# INSERT INTO `luckytokens` (`token`) VALUES ('doHwm');
# INSERT INTO `luckytokens` (`token`) VALUES ('C8OA6');
